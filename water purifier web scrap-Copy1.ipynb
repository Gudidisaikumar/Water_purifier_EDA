# %% [markdown]
# # Innomatics Research labs

# %% [markdown]
# ### Name : G.Sai kumar

# %% [markdown]
# ## Topic :  webscraping  project on water purifier products

# %% [markdown]
# ### Importing the required libraies

# %%
import numpy as np
import pandas as pd
import re 
import time
import requests
from bs4 import BeautifulSoup
import  matplotlib as plt

# %% [markdown]
# ### Extracting the data from the url

# %%
url="https://www.flipkart.com/search?q=water+purifier&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=water+purifier&requestId=20975390-84a0-40ed-b96e-5f71c78955a0&page="

# %%
page=requests.get(url)
pagecontent=page.text
soup=BeautifulSoup(pagecontent)

# %%
page.status_code
# Out:
# 200

# %%
page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="Water Purifier- Buy Products Online at Best Price in India - All Categories | Flipkart.com"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:ipad" content="Flipkart"><meta name="twitter:app:id:ipad" content="742044692"><meta name="twitter:app:url:ipad" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:googleplay" content="Flipkart"><meta name="twitter:app:id:googleplay" content="com.flipkart.android"><meta name="twitter:app:url:googleplay" content="http://dl.flipkart.com/dl/home?"><style>#container {\n\t\t\theight: 100%;\n\t\t}</style><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/runtime.bf6e0956.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/vendor.chunk.0816c45d.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_modules.chunk.fa296a32.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_common.chunk.30b47b30.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app.chunk.6738d282.js" defer="defer" crossorigin="anonymous"></script><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/Browse.chunk.8b36b4.css"/><title>Water Purifier- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title><meta name="og_title" property="og:title" content="Water Purifier- Buy Products Online at Best Price in India - All Categories | Flipkart.com"/><meta name="Keywords" content="Water Purifier"/> <meta name="Description" content="Water Purifier- Buy Products Online at Best Price in India. India&#x27;s Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com"/><meta property="og:description" content="Water Purifier- Buy Products Online at Best Price in India. India&#x27;s Lea ...

# %%
pagecontent
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="Water Purifier- Buy Products Online at Best Price in India - All Categories | Flipkart.com"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:ipad" content="Flipkart"><meta name="twitter:app:id:ipad" content="742044692"><meta name="twitter:app:url:ipad" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:googleplay" content="Flipkart"><meta name="twitter:app:id:googleplay" content="com.flipkart.android"><meta name="twitter:app:url:googleplay" content="http://dl.flipkart.com/dl/home?"><style>#container {\n\t\t\theight: 100%;\n\t\t}</style><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/runtime.bf6e0956.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/vendor.chunk.0816c45d.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_modules.chunk.fa296a32.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_common.chunk.30b47b30.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app.chunk.6738d282.js" defer="defer" crossorigin="anonymous"></script><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/Browse.chunk.8b36b4.css"/><title>Water Purifier- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title><meta name="og_title" property="og:title" content="Water Purifier- Buy Products Online at Best Price in India - All Categories | Flipkart.com"/><meta name="Keywords" content="Water Purifier"/> <meta name="Description" content="Water Purifier- Buy Products Online at Best Price in India. India&#x27;s Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com"/><meta property="og:description" content="Water Purifier- Buy Products Online at Best Price in India. India&#x27;s Lea ...

# %%
names=[]
ratings=[]
specifications=[]
prices=[]
original_costs=[]
discount_offers=[]
type_model=[]
delivery=[]
EMI_offers=[]
for i in range(1,127):
    url="https://www.flipkart.com/search?q=water+purifier&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=water+purifier&requestId=20975390-84a0-40ed-b96e-5f71c78955a0&page={}".format(i)

    page=requests.get(url)
    pagecontent=page.text
    soup=BeautifulSoup(pagecontent)
      
    for data in soup.find_all("div",class_="_3pLy-c row"):
        name=data.find("div",class_="_4rR01T")
        price=data.find("div",class_="_30jeq3 _1_WHN1")
        specification=data.find("ul",class_="_1xgFaf")
        rating=data.find("div",class_="_3LWZlK")
        original_cost=data.find("div",class_="_3I9_wc _27UcVY")
        discount=data.find("div",class_="_3Ay6Sb")
        delivery_offers=data.find("div",class_="_3tcB5a p8ucoS")
        emi=data.find("div",class_="_3xFhiH")
        types=data.find("li",class_="rgWa7D")
        if name is None:
            names.append(np.NaN)
        else:
            names.append(name.text)
            
        if price is None:
            prices.append(np.NaN)
        else:
            prices.append(price.text)
         
        if specification is None:
            specifications.append(np.NaN)
        else:
            specifications.append(specification.text)
            
        if rating is None:
            ratings.append(np.NaN)
        else:
            ratings.append(rating.text)
            
        if original_cost is None:
            original_costs.append(np.NaN)
        else:
            original_costs.append(original_cost.text)
            
        if discount is None:
            discount_offers.append(np.NaN)
        else:
            discount_offers.append(discount.text)
            
        if delivery_offers is None:
            delivery.append(np.NaN)
        else:
            delivery.append(delivery_offers.text)
            
        if emi is None:
            EMI_offers.append(np.NaN)
        else:
            EMI_offers.append(emi.text)
        if types is None:
            type_model.append(np.NaN)
        else:
            type_model.append(types.text)

# %%
print(len(names))
print(len(ratings))
print(len(specifications))
print(len(prices))
print(len(original_costs))
print(len(discount_offers))
print(len(delivery))
print(len(EMI_offers))
print(len(type_model))
# Out:
# 984
# 984
# 984
# 984
# 984
# 984
# 984
# 984
# 984

# %% [markdown]
# ## Creation of the DataFrame

# %%
waterpurifier_df=pd.DataFrame({"Name":names,"Specification":specifications,"Price":prices,"Original_cost":original_costs,"Rating":ratings,"Discount":discount_offers,"Delivery_offers":delivery,"EMI_offers":EMI_offers,"Type_models":type_model})

# %%
waterpurifier_df.head(10)
# Out:
#                                                 Name  \
# 0  KENT Ace Copper 8 L RO + UV + UF + TDS Control...
# 1  KENT Ace Extra/ Ace Alkaline 8 L RO + UV + UF ...
# 2  Aqua Fresh EPICAQUA+RO+UV+UF+TDSADJUSTER 15 L ...
# 3  Aquagrand SkyLand 18 Ltr RO + UV + UF + TDS Wa...
# 4  Pureit Advanced Plus RO+MF+MP 7 L RO + MF Wate...
# 5  Pureit by HUL Advanced Max 6 L Mineral RO + UV...
# 6  V-Guard Zenora RO+MF+MB 7 L RO + MF + MB Water...
# 7        KENT PRISTINE UV 8 L UV + UF Water Purifier
# 8  KENT Ace 8 L RO + UV + UF + TDS Water Purifier...
# 9  Aquagrand AquaXCrux Black Model With Copper Fi...
#
#                                        Specification    Price Original_cost  \
# 0                Electrical & Storage1 Year Warranty  ₹15,999       ₹21,000
# 1  Electrical & Storage1 Year Warranty Provided b...  ₹15,999       ₹21,000
# 2  Electrical & StorageFiltration Capacity: 12 L/...   ₹4,514       ₹16,500
# 3  Electrical & StorageFiltration Capacity: 18 L/...   ₹4,822       ₹14,500
# 4  Electrical & StorageFiltration Capacity: 12 L/...   ₹7,799       ₹11,399
# 5  Electrical & StorageFiltration Capacity: 20 L/...   ₹9,499       ₹18,500
# 6  Electrical & StorageFiltration Capacity: 15 L/...   ₹8,499       ₹12,749
# 7                Electrical & Storage1 Year Warranty   ₹7,999       ₹10,500
# 8  Electrical & Storage1 Year Warranty Provided b...  ₹12,999       ₹19,500
# 9  Electrical & StorageFiltration Capacity: 12 L/...   ₹4,617       ₹12,500
#
#   Rating Discount Delivery_offers                   EMI_offers  \
# 0    4.4  23% off   Free delivery    Upto ₹800 Off on Exchange
# 1    4.4  23% off   Free delivery  Upto ₹1,000 Off on Exchange
# 2    4.1  72% off   Free delivery  No Cost EMI from ₹753/month
# 3      4  66% off   Free delivery                   Bank Offer
# 4    4.5  31% off   Free delivery    Upto ₹200 Off on Exchange
# 5    4.5  48% off   Free delivery    Upto ₹800 Off on Exchange
# 6    4.3  33% off   Free delivery                   Bank Offer
# 7    4.1  23% off   Free delivery                   Bank Offer
# 8    4.4  33% off   Free delivery  Upto ₹1,000 Off on Exchange
# 9    4.3  63% off   Free delivery                   Bank Offer
#
#             Type_models
# 0  Electrical & Storage
# 1  Electrical & Storage
# 2  Electrical & Storage
# 3  Electrical & Storage
# 4  Electrical & Storage
# 5  Electrical & Storage
# 6  Electrical & Storage
# 7  Electrical & Storage
# 8  Electrical & Storage
# 9  Electrical & Storage

# %%
x=waterpurifier_df['Name'].str.split(' ',n=2,expand=True)

# %%
o=x[0] + ' ' + x[1]

# %%
waterpurifier_df["Name"]=o

# %%
waterpurifier_df.head(10)
# Out:
#                   Name                                      Specification  \
# 0             KENT Ace                Electrical & Storage1 Year Warranty
# 1             KENT Ace  Electrical & Storage1 Year Warranty Provided b...
# 2           Aqua Fresh  Electrical & StorageFiltration Capacity: 12 L/...
# 3    Aquagrand SkyLand  Electrical & StorageFiltration Capacity: 18 L/...
# 4      Pureit Advanced  Electrical & StorageFiltration Capacity: 12 L/...
# 5            Pureit by  Electrical & StorageFiltration Capacity: 20 L/...
# 6       V-Guard Zenora  Electrical & StorageFiltration Capacity: 15 L/...
# 7        KENT PRISTINE                Electrical & Storage1 Year Warranty
# 8             KENT Ace  Electrical & Storage1 Year Warranty Provided b...
# 9  Aquagrand AquaXCrux  Electrical & StorageFiltration Capacity: 12 L/...
#
#      Price Original_cost Rating Discount Delivery_offers  \
# 0  ₹15,999       ₹21,000    4.4  23% off   Free delivery
# 1  ₹15,999       ₹21,000    4.4  23% off   Free delivery
# 2   ₹4,514       ₹16,500    4.1  72% off   Free delivery
# 3   ₹4,822       ₹14,500      4  66% off   Free delivery
# 4   ₹7,799       ₹11,399    4.5  31% off   Free delivery
# 5   ₹9,499       ₹18,500    4.5  48% off   Free delivery
# 6   ₹8,499       ₹12,749    4.3  33% off   Free delivery
# 7   ₹7,999       ₹10,500    4.1  23% off   Free delivery
# 8  ₹12,999       ₹19,500    4.4  33% off   Free delivery
# 9   ₹4,617       ₹12,500    4.3  63% off   Free delivery
#
#                     EMI_offers           Type_models
# 0    Upto ₹800 Off on Exchange  Electrical & Storage
# 1  Upto ₹1,000 Off on Exchange  Electrical & Storage
# 2  No Cost EMI from ₹753/month  Electrical & Storage
# 3                   Bank Offer  Electrical & Storage
# 4    Upto ₹200 Off on Exchange  Electrical & Storage
# 5    Upto ₹800 Off on Exchange  Electrical & Storage
# 6                   Bank Offer  Electrical & Storage
# 7                   Bank Offer  Electrical & Storage
# 8  Upto ₹1,000 Off on Exchange  Electrical & Storage
# 9                   Bank Offer  Electrical & Storage

# %%
waterpurifier_df.shape
# Out:
# (984, 9)

# %%
waterpurifier_df.isnull().sum()
# Out:
# Name                 0
# Specification        0
# Price                0
# Original_cost       19
# Rating             248
# Discount            19
# Delivery_offers     79
# EMI_offers           0
# Type_models          0
# dtype: int64

# %%
waterpurifier_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             984 non-null    object
#  1   Specification    984 non-null    object
#  2   Price            984 non-null    object
#  3   Original_cost    965 non-null    object
#  4   Rating           736 non-null    object
#  5   Discount         965 non-null    object
#  6   Delivery_offers  905 non-null    object
#  7   EMI_offers       984 non-null    object
#  8   Type_models      984 non-null    object
# dtypes: object(9)
# memory usage: 69.3+ KB

# %% [markdown]
# # Exporting the data frame into the csv format

# %%
waterpurifier_df.to_csv("D:\Water_purifier2.csv",index=False)

# %%
waterpurifier_df=pd.read_csv(r"D:\Water_purifier2.csv")

# %%
waterpurifier_df
# Out:
#                   Name                                      Specification  \
# 0             KENT Ace                Electrical & Storage1 Year Warranty
# 1             KENT Ace  Electrical & Storage1 Year Warranty Provided b...
# 2           Aqua Fresh  Electrical & StorageFiltration Capacity: 12 L/...
# 3    Aquagrand SkyLand  Electrical & StorageFiltration Capacity: 18 L/...
# 4      Pureit Advanced  Electrical & StorageFiltration Capacity: 12 L/...
# ..                 ...                                                ...
# 979           KENT Ace  Electrical & Storage1 Year Warranty Provided b...
# 980        Blair SWIFT  Electrical & StorageFiltration Capacity: 17 L/...
# 981   Aquamart Advance  Electrical & StorageOFFSITE WARRANTY on ELECTR...
# 982   AquaDart Premium  Electrical & Storage1 Year Warranty On All Ele...
# 983          Blue Star  Electrical & StorageFiltration Capacity: 8 L/h...
#
#        Price Original_cost  Rating Discount Delivery_offers  \
# 0    ₹15,999       ₹21,000     4.4  23% off   Free delivery
# 1    ₹15,999       ₹21,000     4.4  23% off   Free delivery
# 2     ₹4,514       ₹16,500     4.1  72% off   Free delivery
# 3     ₹4,822       ₹14,500     4.0  66% off   Free delivery
# 4     ₹7,799       ₹11,399     4.5  31% off   Free delivery
# ..       ...           ...     ...      ...             ...
# 979  ₹16,299       ₹21,500     4.4  24% off   Free delivery
# 980   ₹4,971       ₹19,999     NaN  75% off   Free delivery
# 981   ₹4,511       ₹19,999     NaN  77% off   Free delivery
# 982   ₹5,399       ₹19,999     3.7  73% off   Free delivery
# 983   ₹8,299       ₹13,400     4.0  38% off   Free delivery
#
#                       EMI_offers           Type_models
# 0      Upto ₹800 Off on Exchange  Electrical & Storage
# 1    Upto ₹1,000 Off on Exchange  Electrical & Storage
# 2    No Cost EMI from ₹753/month  Electrical & Storage
# 3                     Bank Offer  Electrical & Storage
# 4      Upto ₹200 Off on Exchange  Electrical & Storage
# ..                           ...                   ...
# 979  Upto ₹1,000 Off on Exchange  Electrical & Storage
# 980                   Bank Offer  Electrical & Storage
# 981                   Bank Offer  Electrical & Storage
# 982                   Bank Offer  Electrical & Storage
# 983    Upto ₹200 Off on Exchange  Electrical & Storage
#
# [984 rows x 9 columns]
